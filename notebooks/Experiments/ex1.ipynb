# %%
#Changing the working directory to the root
# %cd ../..
# Out:
# c:\Users\olarinoyem\Project\hospitalization_research

# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots as sp
import plotly.io as pio

pio.templates.default = "plotly_white"
from itertools import cycle

from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse
from tqdm.notebook import tqdm

tqdm.pandas()
# import tensorflow as tf
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import pytorch_lightning as pl
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import EarlyStopping

torch.set_float32_matmul_precision("high")
import shutil
from src.utils import plotting_utils
from src.dl.dataloaders import TimeSeriesDataModule
from src.dl.multivariate_models import SingleStepRNNConfig, SingleStepRNNModel

# For reproduceability set a random seed
pl.seed_everything(42)

seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
# Out:
# Seed set to 42

# %%
source_data = Path("data/")


# Check if a GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# try:
#     train_df = pd.read_csv(source_data / "raw/train.csv")
#     test_df = pd.read_csv(source_data / "raw/test.csv")
#     val_df = pd.read_csv(source_data / "raw/val.csv")

# except FileNotFoundError:
#     print("File not found")

try:
    train_df = pd.read_csv(source_data / "raw/targetTransf_train.csv")
    test_df = pd.read_csv(source_data / "raw/targetTransf_test.csv")
    val_df = pd.read_csv(source_data / "raw/targetTransf_val.csv")

except FileNotFoundError:
    print("File not found")

# %%
def format_plot(
    fig, legends=None, xlabel="Time", ylabel="Value", title="", font_size=15
):
    if legends:
        names = cycle(legends)
        fig.for_each_trace(lambda t: t.update(name=next(names)))
    fig.update_layout(
        autosize=False,
        width=900,
        height=500,
        title_text=title,
        title={"x": 0.5, "xanchor": "center", "yanchor": "top"},
        titlefont={"size": 20},
        legend_title=None,
        legend=dict(
            font=dict(size=font_size),
            orientation="h",
            yanchor="bottom",
            y=0.98,
            xanchor="right",
            x=1,
        ),
        yaxis=dict(
            title_text=ylabel,
            titlefont=dict(size=font_size),
            tickfont=dict(size=font_size),
        ),
        xaxis=dict(
            title_text=xlabel,
            titlefont=dict(size=font_size),
            tickfont=dict(size=font_size),
        ),
    )
    return fig


def mase(actual, predicted, insample_actual):
    mae_insample = np.mean(np.abs(np.diff(insample_actual)))
    mae_outsample = np.mean(np.abs(actual - predicted))
    return mae_outsample / mae_insample


def forecast_bias(actual, predicted):
    return np.mean(predicted - actual)


def plot_forecast(
    pred_df, forecast_columns, forecast_display_names=None, save_path=None
):
    if forecast_display_names is None:
        forecast_display_names = forecast_columns
    else:
        assert len(forecast_columns) == len(forecast_display_names)

    mask = ~pred_df[forecast_columns[0]].isnull()
    colors = px.colors.qualitative.Set2  # Using a different color palette
    act_color = colors[0]
    colors = cycle(colors[1:])

    fig = go.Figure()

    # Actual data plot
    fig.add_trace(
        go.Scatter(
            x=pred_df[mask].index,
            y=pred_df[mask].covidOccupiedMVBeds,
            mode="lines",
            marker=dict(size=6, opacity=0.5),
            line=dict(color=act_color, width=2),
            name="Actual COVID-19 MVBeds trends",
        )
    )

    # Predicted data plot
    for col, display_col in zip(forecast_columns, forecast_display_names):
        fig.add_trace(
            go.Scatter(
                x=pred_df[mask].index,
                y=pred_df.loc[mask, col],
                mode="lines+markers",
                marker=dict(size=4),
                line=dict(color=next(colors), width=2),
                name=display_col,
            )
        )

    return fig


def highlight_abs_min(s, props=""):
    return np.where(s == np.nanmin(np.abs(s.values)), props, "")

# %%
# Drop date column and convert data to float32 type
# train = train_df.drop(columns=["Unnamed: 0"])
# val = val_df.drop(columns=["Unnamed: 0"])
# test = test_df.drop(columns=["Unnamed: 0"])

train = train_df.copy()
val = val_df.copy()
test = test_df.copy()

# %%
# Convert date to datetime and set as index
train["date"] = pd.to_datetime(train["date"])
test["date"] = pd.to_datetime(test["date"])
val["date"] = pd.to_datetime(val["date"])

train.set_index("date", inplace=True)
test.set_index("date", inplace=True)
val.set_index("date", inplace=True)

# %%
# Concatenate the DataFrames
sample_df = pd.concat([train, val, test])

# Convert feature columns to float32
# Exclude the 'type' column from conversion as it's a string column
for col in sample_df.columns:
    if col != "type":
        sample_df[col] = sample_df[col].astype("float32")

sample_df.head()
# Out:
#             index  covidOccupiedMVBeds  cumAdmissions  hospitalCases  \
# date
# 2020-07-21  110.0             8.419310       111366.0         1188.0
# 2020-07-22  111.0             7.274678       111448.0         1305.0
# 2020-07-23  112.0             8.012136       111557.0         1095.0
# 2020-07-24  113.0             6.798825       111650.0         1018.0
# 2020-07-25  114.0             5.111784       111715.0          977.0
#
#             newAdmissions  Vax_index  dailyCases  cumulativeCases  \
# date
# 2020-07-21           79.0       0.33       697.0         257316.0
# 2020-07-22           82.0       0.33       764.0         258080.0
# 2020-07-23          109.0       0.33       741.0         258821.0
# 2020-07-24           93.0       0.33       720.0         259541.0
# 2020-07-25           65.0       0.33       499.0         260040.0
#
#             covidOccupiedMVBeds_lag_1  covidOccupiedMVBeds_lag_2  ...  \
# date                                                              ...
# 2020-07-21                      112.0                      119.0  ...
# 2020-07-22                      106.0                      112.0  ...
# 2020-07-23                       97.0                      106.0  ...
# 2020-07-24                      101.0                       97.0  ...
# 2020-07-25                       92.0                      101.0  ...
#
#             _Month_sin_1  _Month_sin_2  _Month_sin_3  _Month_sin_4  \
# date
# 2020-07-21          -0.5      0.866025          -1.0      0.866025
# 2020-07-22          -0.5      0.866025          -1.0      0.866025
# 2020-07-23          -0.5      0.866025          -1.0      0.866025
# 2020-07-24          -0.5      0.866025          -1.0      0.866025
# 2020-07-25          -0.5      0.866025          -1.0      0.866025
#
#             _Month_sin_5  _Month_cos_1  _Month_cos_2  _Month_cos_3  \
# date
# 2020-07-21          -0.5     -0.866025           0.5 -4.286264e-16
# 2020-07-22          -0.5     -0.866025           0.5 -4.286264e-16
# 2020-07-23          -0.5     -0.866025           0.5 -4.286264e-16
# 2020-07-24          -0.5     -0.866025           0.5 -4.286264e-16
# 2020-07-25          -0.5     -0.866025           0.5 -4.286264e-16
#
#             _Month_cos_4  _Month_cos_5
# date
# 2020-07-21          -0.5      0.866025
# 2020-07-22          -0.5      0.866025
# 2020-07-23          -0.5      0.866025
# 2020-07-24          -0.5      0.866025
# 2020-07-25          -0.5      0.866025
#
# [5 rows x 55 columns]

# %%
columns_to_select = [
    "covidOccupiedMVBeds",
    "Vax_index",
    "covidOccupiedMVBeds_lag_1",
    "covidOccupiedMVBeds_lag_2",
    "covidOccupiedMVBeds_lag_3",
    "covidOccupiedMVBeds_lag_7",
    "covidOccupiedMVBeds_lag_14",
    "covidOccupiedMVBeds_lag_21",
    "covidOccupiedMVBeds_roll_3_period_7_mean",
    "hospitalCases_roll_3_period_7_mean",
    "newAdmissions_roll_3_period_7_mean",
    "dailyCases_roll_3_period_7_mean",
    "_WeekDay",
    "_Dayofweek",
    "_Dayofyear",
    "_Month_sin_1",
    "_Month_sin_2",
    "_Month_sin_3",
    "_Month_sin_4",
    "_Month_sin_5",
    "_Month_cos_1",
    "_Month_cos_2",
    "_Month_cos_3",
    "_Month_cos_4",
    "_Month_cos_5",
]

# %%
sample_df = sample_df[columns_to_select]
sample_df.head()
# Out:
#             covidOccupiedMVBeds  Vax_index  covidOccupiedMVBeds_lag_1  \
# date
# 2020-07-21             8.419310       0.33                      112.0
# 2020-07-22             7.274678       0.33                      106.0
# 2020-07-23             8.012136       0.33                       97.0
# 2020-07-24             6.798825       0.33                      101.0
# 2020-07-25             5.111784       0.33                       92.0
#
#             covidOccupiedMVBeds_lag_2  covidOccupiedMVBeds_lag_3  \
# date
# 2020-07-21                      119.0                      118.0
# 2020-07-22                      112.0                      119.0
# 2020-07-23                      106.0                      112.0
# 2020-07-24                       97.0                      106.0
# 2020-07-25                      101.0                       97.0
#
#             covidOccupiedMVBeds_lag_7  covidOccupiedMVBeds_lag_14  \
# date
# 2020-07-21                      123.0                       178.0
# 2020-07-22                      136.0                       164.0
# 2020-07-23                      118.0                       167.0
# 2020-07-24                      122.0                       162.0
# 2020-07-25                      118.0                       152.0
#
#             covidOccupiedMVBeds_lag_21  \
# date
# 2020-07-21                       238.0
# 2020-07-22                       220.0
# 2020-07-23                       211.0
# 2020-07-24                       202.0
# 2020-07-25                       186.0
#
#             covidOccupiedMVBeds_roll_3_period_7_mean  \
# date
# 2020-07-21                                154.809525
# 2020-07-22                                148.952377
# 2020-07-23                                143.714279
# 2020-07-24                                138.476196
# 2020-07-25                                133.523804
#
#             hospitalCases_roll_3_period_7_mean  ...  _Month_sin_1  \
# date                                            ...
# 2020-07-21                         1745.190430  ...          -0.5
# 2020-07-22                         1687.857178  ...          -0.5
# 2020-07-23                         1625.238037  ...          -0.5
# 2020-07-24                         1564.476196  ...          -0.5
# 2020-07-25                         1508.523804  ...          -0.5
#
#             _Month_sin_2  _Month_sin_3  _Month_sin_4  _Month_sin_5  \
# date
# 2020-07-21      0.866025          -1.0      0.866025          -0.5
# 2020-07-22      0.866025          -1.0      0.866025          -0.5
# 2020-07-23      0.866025          -1.0      0.866025          -0.5
# 2020-07-24      0.866025          -1.0      0.866025          -0.5
# 2020-07-25      0.866025          -1.0      0.866025          -0.5
#
#             _Month_cos_1  _Month_cos_2  _Month_cos_3  _Month_cos_4  \
# date
# 2020-07-21     -0.866025           0.5 -4.286264e-16          -0.5
# 2020-07-22     -0.866025           0.5 -4.286264e-16          -0.5
# 2020-07-23     -0.866025           0.5 -4.286264e-16          -0.5
# 2020-07-24     -0.866025           0.5 -4.286264e-16          -0.5
# 2020-07-25     -0.866025           0.5 -4.286264e-16          -0.5
#
#             _Month_cos_5
# date
# 2020-07-21      0.866025
# 2020-07-22      0.866025
# 2020-07-23      0.866025
# 2020-07-24      0.866025
# 2020-07-25      0.866025
#
# [5 rows x 25 columns]

# %%
cols = list(sample_df.columns)
cols.remove("covidOccupiedMVBeds")
sample_df = sample_df[cols + ["covidOccupiedMVBeds"]]

# %%
target = "covidOccupiedMVBeds"
pred_df = pd.concat([train[[target]], val[[target]]])

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1045 entries, 2020-07-21 to 2023-05-31
# Data columns (total 25 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Vax_index                                 1045 non-null   float32
#  1   covidOccupiedMVBeds_lag_1                 1045 non-null   float32
#  2   covidOccupiedMVBeds_lag_2                 1045 non-null   float32
#  3   covidOccupiedMVBeds_lag_3                 1045 non-null   float32
#  4   covidOccupiedMVBeds_lag_7                 1045 non-null   float32
#  5   covidOccupiedMVBeds_lag_14                1045 non-null   float32
#  6   covidOccupiedMVBeds_lag_21                1045 non-null   float32
#  7   covidOccupiedMVBeds_roll_3_period_7_mean  1045 non-null   float32
#  8   hospitalCases_roll_3_period_7_mean        1045 non-null   float32
#  9   newAdmissions_roll_3_period_7_mean        1045 non-null   float32
#  10  dailyCases_roll_3_period_7_mean           1045 non-null   float32
#  11  _WeekDay                                  1045 non-null   float32
#  12  _Dayofweek                                1045 non-null   float32
#  13  _Dayofyear                                1045 non-null   float32
#  14  _Month_sin_1                              1045 non-null   float32
#  15  _Month_sin_2                              1045 non-null   float32
#  16  _Month_sin_3                              1045 non-null   float32
#  17  _Month_sin_4                              1045 non-null   float32
#  18  _Month_sin_5                              1045 non-null   float32
#  19  _Month_cos_1                              1045 non-null   float32
#  20  _Month_cos_2                              1045 non-null   float32
#  21  _Month_cos_3                              1045 non-null   float32
#  22  _Month_cos_4                              1045 non-null   float32
#  23  _Month_cos_5                              1045 non-null   float32
#  24  covidOccupiedMVBeds                       1045 non-null   float32
# dtypes: float32(25)
# memory usage: 110.2 KB

# %%
datamodule = TimeSeriesDataModule(
    data=sample_df,
    n_val=val.shape[0],
    n_test=test.shape[0],
    window=7,  # 7 days window
    horizon=1,  # single step
    normalize="global",  # normalizing the data
    batch_size=64,
    num_workers=0,
)
datamodule.setup()

# %%
# Check a few batches from the training dataloader
train_loader = datamodule.train_dataloader()
for x, y in train_loader:
    print("Input batch shape:", x.shape)
    print("Output batch shape:", y.shape)
    break
# Out:
# Input batch shape: torch.Size([64, 7, 25])
# Output batch shape: torch.Size([64, 1, 1])

# %%
rnn_config = SingleStepRNNConfig(
    rnn_type="LSTM",
    input_size=25,  # 25 for multivariate time series
    hidden_size=128,
    num_layers=6,
    bidirectional=True,
    learning_rate=1e-3,
)
model = SingleStepRNNModel(rnn_config)
model.float()
# Out:
# SingleStepRNNModel(
#   (rnn): LSTM(25, 128, num_layers=6, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=1, bias=True)
#   (loss): MSELoss()
# )

# %%
trainer = pl.Trainer(
    min_epochs=5,
    max_epochs=100,
    callbacks=[pl.callbacks.EarlyStopping(monitor="valid_loss", patience=3)],
)
trainer.fit(model, datamodule)
# Removing artifacts created during training
shutil.rmtree("lightning_logs")
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | LSTM    | 2.1 M
# 1 | fc   | Linear  | 257
# 2 | loss | MSELoss | 0
# ---------------------------------
# 2.1 M     Trainable params
# 0         Non-trainable params
# 2.1 M     Total params
# 8.541     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]

# %%
predictions = trainer.predict(model, datamodule.test_dataloader())
predictions = torch.cat(predictions).squeeze().detach().numpy()
# De-normalizing the predictions
predictions = predictions * datamodule.train.std + datamodule.train.mean

actuals = test["covidOccupiedMVBeds"].values

assert (
    actuals.shape == predictions.shape
), "Mismatch in shapes between actuals and predictions"
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
metric_record = []

# %%
algorithm_name = rnn_config.rnn_type

metrics = {
    "Algorithm": algorithm_name,
    "MAE": mae(actuals, predictions),
    "MSE": mse(actuals, predictions),
    "MASE": mase(actuals, predictions, train["covidOccupiedMVBeds"].values),
    "Forecast Bias": forecast_bias(actuals, predictions),
}

value_formats = ["{}", "{:.4f}", "{:.4f}", "{:.4f}", "{:.2f}"]
metrics = {
    key: format_.format(value)
    for key, value, format_ in zip(metrics.keys(), metrics.values(), value_formats)
}

pred_df_ = pd.DataFrame({"Vanilla LSTM": predictions}, index=test.index)
pred_df = test.join(pred_df_)

metric_record.append(metrics)
print(metrics)
# Out:
# {'Algorithm': 'LSTM', 'MAE': '12.8342', 'MSE': '169.2958', 'MASE': '34.8172', 'Forecast Bias': '-12.83'}

# %%
fig = plot_forecast(
    pred_df,
    forecast_columns=["Vanilla LSTM"],
    forecast_display_names=["Vanilla LSTM"],
)
title = f"Forecasting multivarate COVID-19 MVBeds with {algorithm_name}"
fig = format_plot(fig, title=title)
fig.update_xaxes(
    type="date", range=["2023-01-01", "2023-04-01"], dtick="M1", tickformat="%b %Y"
)
save_path = f"images/forecast_multivarate_{algorithm_name}.png"
# pio.write_image(fig, save_path)
fig.show()

# %% [markdown]
# ### SA_HPT

# %%
def objective(params):
    rnn_type, hidden_size, num_layers, bidirectional, learning_rate = params
    input_size = 12

    rnn_config = SingleStepRNNConfig(
        rnn_type=rnn_type,
        input_size=input_size,
        hidden_size=hidden_size,
        num_layers=num_layers,
        bidirectional=bidirectional,
        learning_rate=learning_rate,
    )
    model = SingleStepRNNModel(rnn_config)

    # Training the model using PyTorch Lightning
    trainer = pl.Trainer(
        max_epochs=100,
        callbacks=[pl.callbacks.EarlyStopping(monitor="valid_loss", patience=3)],
    )
    trainer.fit(model, datamodule)

    predictions = trainer.predict(model, datamodule.test_dataloader())
    predictions = torch.cat(predictions).squeeze().detach().numpy()
    # De-normalizing the predictions
    predictions = predictions * datamodule.train.std + datamodule.train.mean

    actuals = test["covidOccupiedMVBeds"].values

    assert (
        actuals.shape == predictions.shape
    ), "Mismatch in shapes between actuals and predictions"

    # pred = trainer.predict(model, datamodule.test_dataloader())
    # pred = torch.cat(pred).squeeze().detach().numpy()
    # pred = pred * datamodule.train.std + datamodule.train.mean
    # actuals = test[target].values

    return mae(actuals, predictions)

# %%
# Neighbor function to generate a new candidate solution
def neighbor(params):
    rnn_type, hidden_size, num_layers, bidirectional, learning_rate = params

    # Perturbations
    hidden_size = np.random.randint(*param_bounds["hidden_size"])
    num_layers = np.random.randint(*param_bounds["num_layers"])
    learning_rate = np.random.uniform(*param_bounds["learning_rate"])
    rnn_type = np.random.choice(param_bounds["rnn_type"])
    bidirectional = bool(
        np.random.choice(param_bounds["bidirectional"])
    )  # Convert to native boolean

    return [rnn_type, hidden_size, num_layers, bidirectional, learning_rate]


# Cooling schedule (geometric cooling)
def cooling(temp, step):
    return temp * 0.99

# %%
def simulated_annealing(initial_params, initial_temp, steps):
    current_params = initial_params
    current_cost = objective(current_params)
    temp = initial_temp
    costs = [current_cost]
    temperatures = [initial_temp]

    for step in range(steps):
        new_params = neighbor(current_params)
        new_cost = objective(new_params)

        # Acceptance criterion
        if new_cost < current_cost or np.random.uniform(0, 1) < np.exp(
            (current_cost - new_cost) / temp
        ):
            current_params, current_cost = new_params, new_cost

        temp = cooling(temp, step)
        costs.append(current_cost)
        temperatures.append(temp)  # Track temperatures

    return current_params, costs, temperatures

# %%
# Define the bounds for parameters
param_bounds = {
    "rnn_type": ["GRU", "LSTM", "RNN"],
    "hidden_size": (32, 128),
    "num_layers": (5, 50),
    "bidirectional": [True, False],
    "learning_rate": (1e-6, 1e-2),
}

# Initial hyperparameters and temperature
initial_params = ["GRU", 32, 5, True, 1e-2]
initial_temp = 10

# Run Simulated Annealing
best_params, costs, temperatures = simulated_annealing(
    initial_params, initial_temp, 100
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | GRU     | 84.1 K
# 1 | fc   | Linear  | 65
# 2 | loss | MSELoss | 0
# ---------------------------------
# 84.2 K    Trainable params
# 0         Non-trainable params
# 84.2 K    Total params
# 0.337     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | GRU     | 798 K
# 1 | fc   | Linear  | 167
# 2 | loss | MSELoss | 0
# ---------------------------------
# 798 K     Trainable params
# 0         Non-trainable params
# 798 K     Total params
# 3.194     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | GRU     | 673 K
# 1 | fc   | Linear  | 115
# 2 | loss | MSELoss | 0
# ---------------------------------
# 673 K     Trainable params
# 0         Non-trainable params
# 673 K     Total params
# 2.693     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | LSTM    | 113 K
# 1 | fc   | Linear  | 56
# 2 | loss | MSELoss | 0
# ---------------------------------
# 113 K     Trainable params
# 0         Non-trainable params
# 113 K     Total params
# 0.455     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | GRU     | 501 K
# 1 | fc   | Linear  | 123
# 2 | loss | MSELoss | 0
# ---------------------------------
# 501 K     Trainable params
# 0         Non-trainable params
# 501 K     Total params
# 2.006     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | GRU     | 328 K
# 1 | fc   | Linear  | 107
# 2 | loss | MSELoss | 0
# ---------------------------------
# 328 K     Trainable params
# 0         Non-trainable params
# 328 K     Total params
# 1.314     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | RNN     | 140 K
# 1 | fc   | Linear  | 91
# 2 | loss | MSELoss | 0
# ---------------------------------
# 140 K     Trainable params
# 0         Non-trainable params
# 140 K     Total params
# 0.562     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | GRU     | 686 K
# 1 | fc   | Linear  | 187
# 2 | loss | MSELoss | 0
# ---------------------------------
# 687 K     Trainable params
# 0         Non-trainable params
# 687 K     Total params
# 2.748     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | LSTM    | 79.0 K
# 1 | fc   | Linear  | 39
# 2 | loss | MSELoss | 0
# ---------------------------------
# 79.1 K    Trainable params
# 0         Non-trainable params
# 79.1 K    Total params
# 0.316     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | LSTM    | 1.9 M
# 1 | fc   | Linear  | 241
# 2 | loss | MSELoss | 0
# ---------------------------------
# 1.9 M     Trainable params
# 0         Non-trainable params
# 1.9 M     Total params
# 7.466     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | RNN     | 12.8 K
# 1 | fc   | Linear  | 34
# 2 | loss | MSELoss | 0
# ---------------------------------
# 12.8 K    Trainable params
# 0         Non-trainable params
# 12.8 K    Total params
# 0.051     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | LSTM    | 225 K
# 1 | fc   | Linear  | 79
# 2 | loss | MSELoss | 0
# ---------------------------------
# 225 K     Trainable params
# 0         Non-trainable params
# 225 K     Total params
# 0.904     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | LSTM    | 37.1 K
# 1 | fc   | Linear  | 36
# 2 | loss | MSELoss | 0
# ---------------------------------
# 37.1 K    Trainable params
# 0         Non-trainable params
# 37.1 K    Total params
# 0.149     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | LSTM    | 1.1 M
# 1 | fc   | Linear  | 125
# 2 | loss | MSELoss | 0
# ---------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.242     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | RNN     | 97.4 K
# 1 | fc   | Linear  | 94
# 2 | loss | MSELoss | 0
# ---------------------------------
# 97.5 K    Trainable params
# 0         Non-trainable params
# 97.5 K    Total params
# 0.390     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | LSTM    | 1.3 M
# 1 | fc   | Linear  | 187
# 2 | loss | MSELoss | 0
# ---------------------------------
# 1.3 M     Trainable params
# 0         Non-trainable params
# 1.3 M     Total params
# 5.337     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | GRU     | 142 K
# 1 | fc   | Linear  | 115
# 2 | loss | MSELoss | 0
# ---------------------------------
# 142 K     Trainable params
# 0         Non-trainable params
# 142 K     Total params
# 0.571     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | GRU     | 90.7 K
# 1 | fc   | Linear  | 77
# 2 | loss | MSELoss | 0
# ---------------------------------
# 90.8 K    Trainable params
# 0         Non-trainable params
# 90.8 K    Total params
# 0.363     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | GRU     | 81.1 K
# 1 | fc   | Linear  | 40
# 2 | loss | MSELoss | 0
# ---------------------------------
# 81.1 K    Trainable params
# 0         Non-trainable params
# 81.1 K    Total params
# 0.324     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# ...
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | RNN     | 32.8 K
# 1 | fc   | Linear  | 68
# 2 | loss | MSELoss | 0
# ---------------------------------
# 32.8 K    Trainable params
# 0         Non-trainable params
# 32.8 K    Total params
# 0.131     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | RNN     | 27.4 K
# 1 | fc   | Linear  | 87
# 2 | loss | MSELoss | 0
# ---------------------------------
# 27.5 K    Trainable params
# 0         Non-trainable params
# 27.5 K    Total params
# 0.110     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | GRU     | 59.1 K
# 1 | fc   | Linear  | 62
# 2 | loss | MSELoss | 0
# ---------------------------------
# 59.2 K    Trainable params
# 0         Non-trainable params
# 59.2 K    Total params
# 0.237     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | GRU     | 110 K
# 1 | fc   | Linear  | 101
# 2 | loss | MSELoss | 0
# ---------------------------------
# 110 K     Trainable params
# 0         Non-trainable params
# 110 K     Total params
# 0.442     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | RNN     | 28.4 K
# 1 | fc   | Linear  | 41
# 2 | loss | MSELoss | 0
# ---------------------------------
# 28.4 K    Trainable params
# 0         Non-trainable params
# 28.4 K    Total params
# 0.114     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | GRU     | 89.8 K
# 1 | fc   | Linear  | 48
# 2 | loss | MSELoss | 0
# ---------------------------------
# 89.9 K    Trainable params
# 0         Non-trainable params
# 89.9 K    Total params
# 0.359     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
plt.plot(temperatures)
plt.xlabel("Steps")
plt.ylabel("Temperature")
plt.title("Temperature Decay Plot")
plt.show()

# %%
plt.plot(costs)
plt.xlabel("Steps")
plt.ylabel("Objective Value")
plt.title("Convergence Plot")
plt.show()

# %%
print("Best parameters found:", best_params)
# Out:
# Best parameters found: ['RNN', 43, 3, True, 0.0067987679542225584]

# %%
lstm_config = SingleStepRNNConfig(
    rnn_type="RNN",
    input_size=12,  # 7 for multivariate time series
    hidden_size=43,
    num_layers=3,
    bidirectional=True,
    learning_rate=0.006798,
)
model = SingleStepRNNModel(lstm_config)
model.float()

trainer = pl.Trainer(
    min_epochs=5,
    max_epochs=100,
    callbacks=[pl.callbacks.EarlyStopping(monitor="valid_loss", patience=3)],
)
trainer.fit(model, datamodule)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type    | Params
# ---------------------------------
# 0 | rnn  | RNN     | 27.4 K
# 1 | fc   | Linear  | 87
# 2 | loss | MSELoss | 0
# ---------------------------------
# 27.5 K    Trainable params
# 0         Non-trainable params
# 27.5 K    Total params
# 0.110     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]

# %%
predictions = trainer.predict(model, datamodule.test_dataloader())
predictions = torch.cat(predictions).squeeze().detach().numpy()
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\olarinoyem\AppData\Local\miniconda3\envs\pyt_env\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
# De-normalizing the predictions
predictions = predictions * datamodule.train.std + datamodule.train.mean

actuals = test["covidOccupiedMVBeds"].values

assert (
    actuals.shape == predictions.shape
), "Mismatch in shapes between actuals and predictions"

# %%
algorithm_name = lstm_config.rnn_type

metrics = {
    "Algorithm": algorithm_name,
    "MAE": mae(actuals, predictions),
    "MSE": mse(actuals, predictions),
    "MASE": mase(actuals, predictions, train["covidOccupiedMVBeds"].values),
    "Forecast Bias": forecast_bias(actuals, predictions),
}

value_formats = ["{}", "{:.4f}", "{:.4f}", "{:.4f}", "{:.2f}"]
metrics = {
    key: format_.format(value)
    for key, value, format_ in zip(metrics.keys(), metrics.values(), value_formats)
}

metric_record.append(metrics)
print(metrics)
# Out:
# {'Algorithm': 'RNN', 'MAE': '9.7105', 'MSE': '103.3514', 'MASE': '26.3430', 'Forecast Bias': '-9.71'}

# %%
pred_df_ = pd.DataFrame({"LSTM": predictions}, index=test.index)
pred_df = test.join(pred_df_)

# Plotting the forecast
fig = plot_forecast(pred_df, forecast_columns=["LSTM"], forecast_display_names=["LSTM"])
title = f"{lstm_config.rnn_type}: MAE: {metrics['MAE']} | MSE: {metrics['MSE']} | MASE: {metrics['MASE']} | Bias: {metrics['Forecast Bias']}"
fig = format_plot(fig, title=title)
fig.update_xaxes(type="date", range=["2022-10-01", "2022-12-01"])
fig.show()

# %%
metric_df = pd.DataFrame(metric_record)
metric_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Algorithm      2 non-null      object
#  1   MAE            2 non-null      object
#  2   MSE            2 non-null      object
#  3   MASE           2 non-null      object
#  4   Forecast Bias  2 non-null      object
# dtypes: object(5)
# memory usage: 208.0+ bytes

# %%
metric_df[["MAE", "MSE", "MASE", "Forecast Bias"]] = metric_df[
    ["MAE", "MSE", "MASE", "Forecast Bias"]
].astype("float32")

# %%
formatted = metric_df.style.format(
    {
        "MAE": "{:.4f}",
        "MSE": "{:.4f}",
        "MASE": "{:.4f}",
        "Forecast Bias": "{:.2f}%",
        "Time Elapsed": "{:.6f}",
    }
)
formatted = formatted.highlight_min(
    color="lightgreen", subset=["MAE", "MSE", "MASE"]
).apply(
    highlight_abs_min,
    props="color:black;background-color:lightgreen",
    axis=0,
    subset=["Forecast Bias"],
)
formatted
# Out:
# <style type="text/css">
# #T_eb0dc_row1_col1, #T_eb0dc_row1_col2, #T_eb0dc_row1_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_eb0dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb0dc_level0_col0" class="col_heading level0 col0" >Algorithm</th>
#       <th id="T_eb0dc_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_eb0dc_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_eb0dc_level0_col3" class="col_heading level0 col3" >MASE</th>
#       <th id="T_eb0dc_level0_col4" class="col_heading level0 col4" >Forecast Bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb0dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb0dc_row0_col0" class="data row0 col0" >LSTM</td>
#       <td id="T_eb0dc_row0_col1" class="data row0 col1" >12.7302</td>
#       <td id="T_eb0dc_row0_col2" class="data row0 col2" >162.8821</td>
#       <td id="T_eb0dc_row0_col3" class="data row0 col3" >34.5349</td>
#       <td id="T_eb0dc_row0_col4" class="data row0 col4" >-12.73%</td>
#     </tr>
#     <tr>
#       <th id="T_eb0dc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb0dc_row1_col0" class="data row1 col0" >RNN</td>
#       <td id="T_eb0dc_row1_col1" class="data row1 col1" >9.7105</td>
#       <td id="T_eb0dc_row1_col2" class="data row1 col2" >103.3514</td>
#       <td id="T_eb0dc_row1_col3" class="data row1 col3" >26.3430</td>
#       <td id="T_eb0dc_row1_col4" class="data row1 col4" >-9.71%</td>
#     </tr>
#   </tbody>
# </table>
